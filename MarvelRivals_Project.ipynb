# %% [markdown]
# # **INFO:**
#
# Check the bottom of this doc for project info. I wanted to test the API first to see if the data necessary to complete it could even be gathered before a write up.
# ***

# %% [markdown]
# Testing the Marvel Rivals API
#
# key:
#
# rate limit: 500 requests per minute

# %%
# Advanced example with session management and retries
import requests
from requests.adapters import HTTPAdapter
from requests.packages.urllib3.util.retry import Retry
import pandas as pd
import json
import time
import numpy as np
import matplotlib.pyplot as plt

# %%
# Define common parameters

# api/player-match/{id} needs the UID of the player not the name
player_id = 946297425 # For WoozyMckay

# API key from Lunar Client
API_key = ''

# %%
# Define the API client
class MRAPIClient:
    def __init__(self, base_url='https://mrapi.org'):
        self.base_url = base_url
        self.session = requests.Session()

        retry_strategy = Retry(
            total=3,
            backoff_factor=1,
            status_forcelist=[500, 502, 503, 504]
        )

        adapter = HTTPAdapter(max_retries=retry_strategy)
        self.session.mount("http://", adapter)
        self.session.mount("https://", adapter)

    def get_data(self, endpoint):
        try:
            response = self.session.get(f"{self.base_url}{endpoint}", headers={'X-API-Key': {API_key}})
            response.raise_for_status()
            return response.json()
        except requests.exceptions.RequestException as e:
            print(f"Error fetching data: {e}")
            raise

# %%
client = MRAPIClient()
data = client.get_data('/api/player-match/946297425')
print(data)
# Out:
# [{'match_timestamp': 1739048473, 'match_duration': {'minutes': 7, 'seconds': 49, 'raw': 469}, 'season': '2', 'match_uid': '6714034_1739047847_94_11001_10', 'match_map': {'id': 1170, 'name': 'Royal Palace - Yggsgard', 'gamemode': 'domination'}, 'score': {'ally': 2, 'enemy': 2}, 'winner_side': 0, 'mvp_uid': 851765237, 'svp_uid': 946297425, 'gamemode': {'id': 1, 'name': 'quick-play'}, 'stats': {'kills': 5, 'deaths': 6, 'assists': 5, 'is_win': False, 'has_escaped': False, 'hero': {'id': 1031}}}, {'match_timestamp': 1738984433, 'match_duration': {'minutes': 7, 'seconds': 39, 'raw': 459}, 'season': '2', 'match_uid': '6713872_1738983799_755_11001_10', 'match_map': {'id': 1272, 'name': "Birnin T'Challa - Intergalactic Empire of Wakanda", 'gamemode': 'domination'}, 'score': {'ally': 2, 'enemy': 2}, 'winner_side': 0, 'mvp_uid': 536679700, 'svp_uid': 951112935, 'gamemode': {'id': 2, 'name': 'competitive'}, 'stats': {'kills': 3, 'deaths': 6, 'assists': 3, 'is_win': False, 'has_escaped': False, 'hero': {'id': 1015}}}, {'match_timestamp': 1738716504, 'match_duration': {'minutes': 10, 'seconds': 46, 'raw': 646}, 'season': '2', 'match_uid': '4890706_1738715635_70_11001_10', 'match_map': {'id': 1272, 'name': "Birnin T'Challa - Intergalactic Empire of Wakanda", 'gamemode': 'domination'}, 'score': {'ally': 1, 'enemy': 1}, 'winner_side': 1, 'mvp_uid': 597511711, 'svp_uid': 1602193538, 'gamemode': {'id': 2, 'name': 'competitive'}, 'stats': {'kills': 20, 'deaths': 5, 'assists': 3, 'is_win': True, 'has_escaped': False, 'hero': {'id': 1041}}}, {'match_timestamp': 1738708425, 'match_duration': {'minutes': 11, 'seconds': 29, 'raw': 689}, 'season': '2', 'match_uid': '6713712_1738707645_728_11001_10', 'match_map': {'id': 1101, 'name': 'Hall of Djalia - Intergalactic Empire of Wakanda', 'gamemode': 'convergence'}, 'score': {}, 'winner_side': 0, 'mvp_uid': 1729261467, 'svp_uid': 510830805, 'gamemode': {'id': 1, 'name': 'quick-play'}, 'stats': {'kills': 20, 'deaths': 6, 'assists': 0, 'is_win': False, 'has_escaped': False, 'hero': {'id': 1048}}}, {'match_timestamp': 1738472543, 'match_duration': {'minutes': 8, 'seconds': 9, 'raw': 489}, 'season': '2', 'match_uid': '6713494_1738471964_628_11001_10', 'match_map': {'id': 1101, 'name': 'Hall of Djalia - Intergalactic Empire of Wakanda', 'gamemode': 'convergence'}, 'score': {}, 'winner_side': 1, 'mvp_uid': 1811191434, 'svp_uid': 747941503, 'gamemode': {'id': 1, 'name': 'quick-play'}, 'stats': {'kills': 7, 'deaths': 6, 'assists': 1, 'is_win': False, 'has_escaped': False, 'hero': {'id': 1033}}}, {'match_timestamp': 1738471812, 'match_duration': {'minutes': 6, 'seconds': 58, 'raw': 418}, 'season': '2', 'match_uid': '6713530_1738471301_187_11001_10', 'match_map': {'id': 1101, 'name': 'Hall of Djalia - Intergalactic Empire of Wakanda', 'gamemode': 'convergence'}, 'score': {}, 'winner_side': 0, 'mvp_uid': 1935871575, 'svp_uid': 1768923224, 'gamemode': {'id': 1, 'name': 'quick-play'}, 'stats': {'kills': 17, 'deaths': 1, 'assists': 1, 'is_win': True, 'has_escaped': False, 'hero': {'id': 1033}}}, {'match_timestamp': 1738127290, 'match_duration': {'minutes': 17, 'seconds': 2, 'raw': 1022}, 'season': '2', 'match_uid': '6713849_1738126045_816_11001_10', 'match_map': {'id': 1291, 'name': 'Midtown - Empire of Eternal Night', 'gamemode': 'convoy'}, 'score': {'ally': 3, 'enemy': 3}, 'winner_side': 0, 'mvp_uid': 936055193, 'svp_uid': 1225899974, 'gamemode': {'id': 2, 'name': 'competitive'}, 'stats': {'kills': 20, 'deaths': 5, 'assists': 37, 'is_win': True, 'has_escaped': False, 'hero': {'id': 1031}}}, {'match_timestamp': 1738125133, 'match_duration': {'minutes': 4, 'seconds': 22, 'raw': 262}, 'season': '2', 'match_uid': '6714917_1738124779_527_11001_10', 'match_map': {'id': 1034, 'name': 'Shin-Shibuya - Tokyo 2099', 'gamemode': 'convergence'}, 'score': {}, 'winner_side': 0, 'mvp_uid': 432152608, 'svp_uid': 403803439, 'gamemode': {'id': 1, 'name': 'quick-play'}, 'stats': {'kills': 13, 'deaths': 1, 'assists': 0, 'is_win': True, 'ha ...

# %%
df = pd.DataFrame(data)
display(df)
# Out:
#     match_timestamp                              match_duration season  \
# 0        1739048473   {'minutes': 7, 'seconds': 49, 'raw': 469}      2
# 1        1738984433   {'minutes': 7, 'seconds': 39, 'raw': 459}      2
# 2        1738716504  {'minutes': 10, 'seconds': 46, 'raw': 646}      2
# 3        1738708425  {'minutes': 11, 'seconds': 29, 'raw': 689}      2
# 4        1738472543    {'minutes': 8, 'seconds': 9, 'raw': 489}      2
# 5        1738471812   {'minutes': 6, 'seconds': 58, 'raw': 418}      2
# 6        1738127290  {'minutes': 17, 'seconds': 2, 'raw': 1022}      2
# 7        1738125133   {'minutes': 4, 'seconds': 22, 'raw': 262}      2
# 8        1738085641    {'minutes': 8, 'seconds': 5, 'raw': 485}      2
# 9        1737758372   {'minutes': 8, 'seconds': 49, 'raw': 529}      2
# 10       1737682577  {'minutes': 10, 'seconds': 34, 'raw': 634}      2
# 11       1737652851   {'minutes': 8, 'seconds': 44, 'raw': 524}      2
# 12       1737497148  {'minutes': 14, 'seconds': 35, 'raw': 875}      2
# 13       1737321423   {'minutes': 9, 'seconds': 26, 'raw': 566}      2
# 14       1737257472   {'minutes': 7, 'seconds': 30, 'raw': 450}      2
# 15       1737217973   {'minutes': 8, 'seconds': 59, 'raw': 539}      2
# 16       1737130550   {'minutes': 10, 'seconds': 1, 'raw': 601}      2
# 17       1737080797  {'minutes': 12, 'seconds': 42, 'raw': 762}      2
# 18       1737079396  {'minutes': 12, 'seconds': 47, 'raw': 767}      2
# 19       1737076518  {'minutes': 15, 'seconds': 11, 'raw': 911}      2
#
#                           match_uid  \
# 0    6714034_1739047847_94_11001_10
# 1   6713872_1738983799_755_11001_10
# 2    4890706_1738715635_70_11001_10
# 3   6713712_1738707645_728_11001_10
# 4   6713494_1738471964_628_11001_10
# 5   6713530_1738471301_187_11001_10
# 6   6713849_1738126045_816_11001_10
# 7   6714917_1738124779_527_11001_10
# 8   6713662_1738084929_110_11001_10
# 9   6713643_1737757676_743_11001_10
# 10  6714041_1737681747_560_11001_10
# 11  6713658_1737652077_166_11001_10
# 12   6714560_1737496044_85_11001_10
# 13  6713689_1737320655_332_11001_10
# 14  6714235_1737256844_925_11001_10
# 15  6713695_1737217222_178_11001_10
# 16  4890825_1737129860_130_11001_10
# 17  6713804_1737079817_728_11001_10
# 18  6714104_1737078417_532_11001_10
# 19  6714077_1737075380_398_11001_10
#
#                                             match_map  \
# 0   {'id': 1170, 'name': 'Royal Palace - Yggsgard'...
# 1   {'id': 1272, 'name': 'Birnin T'Challa - Interg...
# 2   {'id': 1272, 'name': 'Birnin T'Challa - Interg...
# 3   {'id': 1101, 'name': 'Hall of Djalia - Interga...
# 4   {'id': 1101, 'name': 'Hall of Djalia - Interga...
# 5   {'id': 1101, 'name': 'Hall of Djalia - Interga...
# 6   {'id': 1291, 'name': 'Midtown - Empire of Eter...
# 7   {'id': 1034, 'name': 'Shin-Shibuya - Tokyo 209...
# 8   {'id': 1267, 'name': 'Hall of Djalia - Interga...
# 9   {'id': 1288, 'name': 'Hell's Heaven - Hydra Ch...
# 10  {'id': 1267, 'name': 'Hall of Djalia - Interga...
# 11  {'id': 1245, 'name': 'Spider-Islands - Tokyo 2...
# 12  {'id': 1267, 'name': 'Hall of Djalia - Interga...
# 13  {'id': 1231, 'name': 'Yggdrasill Path - Yggsga...
# 14  {'id': 1288, 'name': 'Hell's Heaven - Hydra Ch...
# 15  {'id': 1230, 'name': 'Shin-Shibuya - Tokyo 209...
# 16  {'id': 1032, 'name': 'Yggdrasill Path - Yggsga...
# 17  {'id': 1291, 'name': 'Midtown - Empire of Eter...
# 18  {'id': 1231, 'name': 'Yggdrasill Path - Yggsga...
# 19  {'id': 1291, 'name': 'Midtown - Empire of Eter...
#
#                       score  winner_side     mvp_uid     svp_uid  \
# 0   {'ally': 2, 'enemy': 2}            0   851765237   946297425
# 1   {'ally': 2, 'enemy': 2}            0   536679700   951112935
# 2   {'ally': 1, 'enemy': 1}            1   597511711  1602193538
# 3                        {}            0  1729261467   510830805
# 4                        {}            1  1811191434   747941503
# 5                        {}            0  1935871575  1768923224
# 6   {'ally': 3, 'enemy': 3}            0   936055193  1225899974
# 7                        {}            0   432152608   403803439
# 8   {'ally': 0, 'enemy': 0}            1   972498423   962752765
# 9   {'ally': 0, 'enemy': 0}            1  1178622012   164334222
# 10  {'ally': 1, 'enemy': 1}            1   118874257   978317062
# 11  {'ally': 1, 'enemy': 1}            0   215695363  2084598864
# 12  {'ally': 1, 'enemy': 1}            1   862397886  1457706645
# 13  {'ally': 1, 'enemy': 1}            1   216102186  1853018536
# 14  {'ally': 2, 'enemy': 2}            0   514251058   657784701
# 15  {'ally': 1, 'enemy': 1}            1   575146068   841817973
# 16                       {}            1   946297425  2090531280
# 17  {'ally': 2, 'enemy': 2}            0  2058127479   950135016
# 18  {'ally': 3, 'enemy': 3}            0  1748540617   313722922
# 19  {'ally': 2, 'enemy': 2}            1   946297425  2085445542
#
#                             gamemode  \
# 0    {'id': 1, 'name': 'quick-play'}
# 1   {'id': 2, 'name': 'competitive'}
# 2   {'id': 2, 'name': 'competitive'}
# 3    {'id': 1, 'name': 'quick-play'}
# 4    {'id': 1, 'name': 'quick-play'}
# 5    {'id': 1, 'name': 'quick-play'}
# 6   {'id': 2, 'name': 'competitive'}
# 7    {'id': 1, 'name': 'quick-play'}
# 8   {'id': 2, 'name': 'competitive'}
# 9   {'id': 2, 'name': 'competitive'}
# 10  {'id': 2, 'name': 'competitive'}
# 11  {'id': 2, 'name': 'competitive'}
# 12  {'id': 2, 'name': 'competitive'}
# 13  {'id': 2, 'name': 'competitive'}
# 14  {'id': 2, 'name': 'competitive'}
# 15  {'id': 2, 'name': 'competitive'}
# 16   {'id': 1, 'name': 'quick-play'}
# 17  {'id': 2, 'name': 'competitive'}
# 18  {'id': 2, 'name': 'competitive'}
# 19  {'id': 2, 'name': 'competitive'}
#
#                                                 stats
# 0   {'kills': 5, 'deaths': 6, 'assists': 5, 'is_wi...
# 1   {'kills': 3, 'deaths': 6, 'assists': 3, 'is_wi...
# 2   {'kills': 20, 'deaths': 5, 'assists': 3, 'is_w...
# 3   {'kills': 20, 'deaths': 6, 'assists': 0, 'is_w...
# 4   {'kills': 7, 'deaths': 6, 'assists': 1, 'is_wi...
# 5   {'kills': 17, 'deaths': 1, 'assists': 1, 'is_w...
# 6   {'kills': 20, 'deaths': 5, 'assists': 37, 'is_...
# 7   {'kills': 13, 'deaths': 1, 'assists': 0, 'is_w...
# 8   {'kills': 6, 'deaths': 6, 'assists': 0, 'is_wi...
# 9   {'kills': 22, 'deaths': 8, 'assists': 4, 'is_w...
# 10  {'kills': 20, 'deaths': 6, 'assists': 1, 'is_w...
# 11  {'kills': 17, 'deaths': 5, 'assists': 0, 'is_w...
# 12  {'kills': 31, 'deaths': 9, 'assists': 5, 'is_w...
# 13  {'kills': 35, 'deaths': 4, 'assists': 11, 'is_...
# 14  {'kills': 10, 'deaths': 6, 'assists': 0, 'is_w...
# 15  {'kills': 26, 'deaths': 1, 'assists': 8, 'is_w...
# 16  {'kills': 48, 'deaths': 4, 'assists': 8, 'is_w...
# 17  {'kills': 16, 'deaths': 11, 'assists': 8, 'is_...
# 18  {'kills': 8, 'deaths': 10, 'assists': 17, 'is_...
# 19  {'kills': 26, 'deaths': 10, 'assists': 7, 'is_...

# %% [markdown]
# Lets take a quick look at the stats header

# %%
stats_data = df['stats']
stats_df = pd.json_normalize(stats_data)
stats_df.index = df['match_uid']
display(stats_df)
# Out:
#                                  kills  deaths  assists  is_win  has_escaped  \
# match_uid
# 6714034_1739047847_94_11001_10       5       6        5   False        False
# 6713872_1738983799_755_11001_10      3       6        3   False        False
# 4890706_1738715635_70_11001_10      20       5        3    True        False
# 6713712_1738707645_728_11001_10     20       6        0   False        False
# 6713494_1738471964_628_11001_10      7       6        1   False        False
# 6713530_1738471301_187_11001_10     17       1        1    True        False
# 6713849_1738126045_816_11001_10     20       5       37    True        False
# 6714917_1738124779_527_11001_10     13       1        0    True        False
# 6713662_1738084929_110_11001_10      6       6        0   False        False
# 6713643_1737757676_743_11001_10     22       8        4   False        False
# 6714041_1737681747_560_11001_10     20       6        1    True        False
# 6713658_1737652077_166_11001_10     17       5        0    True        False
# 6714560_1737496044_85_11001_10      31       9        5    True        False
# 6713689_1737320655_332_11001_10     35       4       11    True        False
# 6714235_1737256844_925_11001_10     10       6        0   False        False
# 6713695_1737217222_178_11001_10     26       1        8    True        False
# 4890825_1737129860_130_11001_10     48       4        8    True        False
# 6713804_1737079817_728_11001_10     16      11        8   False        False
# 6714104_1737078417_532_11001_10      8      10       17   False        False
# 6714077_1737075380_398_11001_10     26      10        7    True        False
#
#                                  hero.id
# match_uid
# 6714034_1739047847_94_11001_10      1031
# 6713872_1738983799_755_11001_10     1015
# 4890706_1738715635_70_11001_10      1041
# 6713712_1738707645_728_11001_10     1048
# 6713494_1738471964_628_11001_10     1033
# 6713530_1738471301_187_11001_10     1033
# 6713849_1738126045_816_11001_10     1031
# 6714917_1738124779_527_11001_10     1029
# 6713662_1738084929_110_11001_10     1027
# 6713643_1737757676_743_11001_10     1041
# 6714041_1737681747_560_11001_10     1048
# 6713658_1737652077_166_11001_10     1030
# 6714560_1737496044_85_11001_10      1041
# 6713689_1737320655_332_11001_10     1015
# 6714235_1737256844_925_11001_10     1024
# 6713695_1737217222_178_11001_10     1015
# 4890825_1737129860_130_11001_10     1015
# 6713804_1737079817_728_11001_10     1032
# 6714104_1737078417_532_11001_10     1025
# 6714077_1737075380_398_11001_10     1050

# %% [markdown]
# ***
# ### Initial Thoughts
#
# Generally speaking, it seems that we only gather about 20 matches, there's likely some way to persist it, however this doesn't matter all that much. Individual stats are gathered for the player, but we're more curious about the stats overall for the match.
#
# We likely want to take the output here from the Match id, then plug that into more api requests for the match itself.

# %%
matches = df['match_uid'].to_list() 
print(matches)
# Out:
# ['6714034_1739047847_94_11001_10', '6713872_1738983799_755_11001_10', '4890706_1738715635_70_11001_10', '6713712_1738707645_728_11001_10', '6713494_1738471964_628_11001_10', '6713530_1738471301_187_11001_10', '6713849_1738126045_816_11001_10', '6714917_1738124779_527_11001_10', '6713662_1738084929_110_11001_10', '6713643_1737757676_743_11001_10', '6714041_1737681747_560_11001_10', '6713658_1737652077_166_11001_10', '6714560_1737496044_85_11001_10', '6713689_1737320655_332_11001_10', '6714235_1737256844_925_11001_10', '6713695_1737217222_178_11001_10', '4890825_1737129860_130_11001_10', '6713804_1737079817_728_11001_10', '6714104_1737078417_532_11001_10', '6714077_1737075380_398_11001_10']

# %%
match_data = client.get_data('/api/match/6714034_1739047847_94_11001_10')
print(match_data)
# Out:
# {'match_uid': '6714034_1739047847_94_11001_10', 'replay_id': '10477527920', 'mvp': {'player_uid': 851765237, 'hero_id': 1027}, 'svp': {'player_uid': 946297425, 'hero_id': 1041}, 'gamemode': {'id': 1, 'name': 'quick-play'}, 'players': [{'player_uid': 1760979252, 'name': 'Boogerscrotum', 'hero_id': 1050, 'is_win': False, 'kills': 2, 'deaths': 4, 'assists': 3, 'hero_damage': 1434, 'hero_healed': 6792.121636390686, 'damage_taken': 5171.407166004181, 'heroes': [{'hero_id': 1050, 'playtime': {'minutes': 7, 'seconds': 39, 'raw': 459}, 'kills': 2, 'deaths': 4, 'assists': 3, 'hit_rate': 0.5477707006369427}]}, {'player_uid': 2060844458, 'name': 'SpiderManBulge', 'hero_id': 1023, 'is_win': False, 'kills': 3, 'deaths': 8, 'assists': 3, 'hero_damage': 6320.204075336456, 'hero_healed': 2842.7498240470886, 'damage_taken': 11076.655098438263, 'heroes': [{'hero_id': 1040, 'playtime': {'seconds': 0, 'raw': 0}, 'kills': 0, 'deaths': 0, 'assists': 0, 'hit_rate': 0}, {'hero_id': 1039, 'playtime': {'minutes': 2, 'seconds': 33, 'raw': 153}, 'kills': 0, 'deaths': 3, 'assists': 1, 'hit_rate': 0.475}, {'hero_id': 1041, 'playtime': {'minutes': 1, 'seconds': 42, 'raw': 102}, 'kills': 3, 'deaths': 2, 'assists': 0, 'hit_rate': 0.5405405405405406}, {'hero_id': 1023, 'playtime': {'minutes': 3, 'seconds': 35, 'raw': 215}, 'kills': 0, 'deaths': 3, 'assists': 2, 'hit_rate': 0.3256484149855908}]}, {'player_uid': 946297425, 'name': 'WoozyMckay', 'hero_id': 1041, 'is_win': False, 'kills': 5, 'deaths': 6, 'assists': 5, 'hero_damage': 7897.712778091431, 'hero_healed': 6203.631268024445, 'damage_taken': 3900.4799575805664, 'heroes': [{'hero_id': 1031, 'playtime': {'minutes': 2, 'seconds': 58, 'raw': 178}, 'kills': 0, 'deaths': 2, 'assists': 4, 'hit_rate': 0.5173745173745173}, {'hero_id': 1024, 'playtime': {'minutes': 1, 'seconds': 16, 'raw': 76}, 'kills': 3, 'deaths': 1, 'assists': 0, 'hit_rate': 0.5}, {'hero_id': 1021, 'playtime': {'minutes': 1, 'seconds': 33, 'raw': 93}, 'kills': 1, 'deaths': 1, 'assists': 0, 'hit_rate': 0.5}, {'hero_id': 1041, 'playtime': {'minutes': 2, 'seconds': 3, 'raw': 123}, 'kills': 1, 'deaths': 2, 'assists': 1, 'hit_rate': 0.3584905660377358}]}, {'player_uid': 294125044, 'name': 'Portal112', 'hero_id': 1029, 'is_win': False, 'kills': 10, 'deaths': 8, 'assists': 0, 'hero_damage': 5170.035369873047, 'hero_healed': 0, 'damage_taken': 4896.128410816193, 'heroes': [{'hero_id': 1029, 'playtime': {'minutes': 7, 'seconds': 49, 'raw': 469}, 'kills': 10, 'deaths': 8, 'assists': 0, 'hit_rate': 0.4745762711864407}]}, {'player_uid': 1816976623, 'name': 'DraconianSpy', 'hero_id': 1018, 'is_win': False, 'kills': 4, 'deaths': 6, 'assists': 0, 'hero_damage': 6029.96666431427, 'hero_healed': 0, 'damage_taken': 19273.281858205795, 'heroes': [{'hero_id': 1011, 'playtime': {'minutes': 5, 'seconds': 9, 'raw': 309}, 'kills': 4, 'deaths': 3, 'assists': 0, 'hit_rate': 0.5064935064935064}, {'hero_id': 1018, 'playtime': {'minutes': 2, 'seconds': 40, 'raw': 160}, 'kills': 0, 'deaths': 3, 'assists': 0, 'hit_rate': 0.25161290322580643}]}, {'player_uid': 805995708, 'name': 'Pilot_Service', 'hero_id': 1042, 'is_win': False, 'kills': 8, 'deaths': 8, 'assists': 0, 'hero_damage': 9626.563036441803, 'hero_healed': 945.8802490234375, 'damage_taken': 8636.996515750885, 'heroes': [{'hero_id': 1048, 'playtime': {'minutes': 4, 'seconds': 14, 'raw': 254}, 'kills': 5, 'deaths': 3, 'assists': 0, 'hit_rate': 0.42053445850914206}, {'hero_id': 1042, 'playtime': {'minutes': 3, 'seconds': 35, 'raw': 215}, 'kills': 3, 'deaths': 5, 'assists': 0, 'hit_rate': 0.5263157894736842}]}, {'player_uid': 851765237, 'name': 'Super_49', 'hero_id': 1027, 'is_win': True, 'kills': 24, 'deaths': 3, 'assists': 0, 'hero_damage': 11634.407031059265, 'hero_healed': 0, 'damage_taken': 14727.332697868347, 'heroes': [{'hero_id': 1027, 'playtime': {'minutes': 7, 'seconds': 49, 'raw': 469}, 'kills': 24, 'deaths': 3, 'assists': 0, 'hit_rate': 0.5434782608695652}]}, {'player_uid': 553022362, 'name': 'melody_69', 'her ...

# %%
match_df = pd.json_normalize(match_data)
display(match_df)
# Out:
#                         match_uid    replay_id  \
# 0  6714034_1739047847_94_11001_10  10477527920
#
#                                              players  mvp.player_uid  \
# 0  [{'player_uid': 1760979252, 'name': 'Boogerscr...       851765237
#
#    mvp.hero_id  svp.player_uid  svp.hero_id  gamemode.id gamemode.name
# 0         1027       946297425         1041            1    quick-play

# %%
# we're more interested in the player data
player_data = match_data['players']
player_df = pd.json_normalize(player_data)
display(player_df)
# Out:
#     player_uid            name  hero_id  is_win  kills  deaths  assists  \
# 0   1760979252   Boogerscrotum     1050   False      2       4        3
# 1   2060844458  SpiderManBulge     1023   False      3       8        3
# 2    946297425      WoozyMckay     1041   False      5       6        5
# 3    294125044       Portal112     1029   False     10       8        0
# 4   1816976623    DraconianSpy     1018   False      4       6        0
# 5    805995708   Pilot_Service     1042   False      8       8        0
# 6    851765237        Super_49     1027    True     24       3        0
# 7    553022362       melody_69     1038    True     18       3        2
# 8   1972373663        AK47-404     1037    True     16       2        0
# 9    228809324     Bonehead.99     1023    True     10       3       17
# 10  1274628249           T'emp     1031    True     17       4        6
# 11   753574328      Saibothero     1043    True     15       7        0
#
#      hero_damage   hero_healed  damage_taken  \
# 0    1434.000000   6792.121636   5171.407166
# 1    6320.204075   2842.749824  11076.655098
# 2    7897.712778   6203.631268   3900.479958
# 3    5170.035370      0.000000   4896.128411
# 4    6029.966664      0.000000  19273.281858
# 5    9626.563036    945.880249   8636.996516
# 6   11634.407031      0.000000  14727.332698
# 7    6870.429959      0.000000   4459.110641
# 8    9119.925743      0.000000  14869.671930
# 9    3216.973350  12075.260708   3853.433267
# 10   6101.363370  12107.202241   3944.001816
# 11   8235.985533      0.000000   3774.297572
#
#                                                heroes
# 0   [{'hero_id': 1050, 'playtime': {'minutes': 7, ...
# 1   [{'hero_id': 1040, 'playtime': {'seconds': 0, ...
# 2   [{'hero_id': 1031, 'playtime': {'minutes': 2, ...
# 3   [{'hero_id': 1029, 'playtime': {'minutes': 7, ...
# 4   [{'hero_id': 1011, 'playtime': {'minutes': 5, ...
# 5   [{'hero_id': 1048, 'playtime': {'minutes': 4, ...
# 6   [{'hero_id': 1027, 'playtime': {'minutes': 7, ...
# 7   [{'hero_id': 1038, 'playtime': {'minutes': 7, ...
# 8   [{'hero_id': 1037, 'playtime': {'minutes': 7, ...
# 9   [{'hero_id': 1023, 'playtime': {'minutes': 7, ...
# 10  [{'hero_id': 1031, 'playtime': {'minutes': 7, ...
# 11  [{'hero_id': 1043, 'playtime': {'minutes': 7, ...

# %%
# lets look at the hero data as well
hero_data = player_df['heroes']
hero_df = pd.json_normalize(hero_data)
display(hero_df)
# Out:
#                                                     0  \
# 0   {'hero_id': 1050, 'kills': 2, 'deaths': 4, 'as...
# 1   {'hero_id': 1040, 'kills': 0, 'deaths': 0, 'as...
# 2   {'hero_id': 1031, 'kills': 0, 'deaths': 2, 'as...
# 3   {'hero_id': 1029, 'kills': 10, 'deaths': 8, 'a...
# 4   {'hero_id': 1011, 'kills': 4, 'deaths': 3, 'as...
# 5   {'hero_id': 1048, 'kills': 5, 'deaths': 3, 'as...
# 6   {'hero_id': 1027, 'kills': 24, 'deaths': 3, 'a...
# 7   {'hero_id': 1038, 'kills': 18, 'deaths': 3, 'a...
# 8   {'hero_id': 1037, 'kills': 16, 'deaths': 2, 'a...
# 9   {'hero_id': 1023, 'kills': 10, 'deaths': 3, 'a...
# 10  {'hero_id': 1031, 'kills': 17, 'deaths': 4, 'a...
# 11  {'hero_id': 1043, 'kills': 15, 'deaths': 7, 'a...
#
#                                                     1  \
# 0                                                None
# 1   {'hero_id': 1039, 'kills': 0, 'deaths': 3, 'as...
# 2   {'hero_id': 1024, 'kills': 3, 'deaths': 1, 'as...
# 3                                                None
# 4   {'hero_id': 1018, 'kills': 0, 'deaths': 3, 'as...
# 5   {'hero_id': 1042, 'kills': 3, 'deaths': 5, 'as...
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
#
#                                                     2  \
# 0                                                None
# 1   {'hero_id': 1041, 'kills': 3, 'deaths': 2, 'as...
# 2   {'hero_id': 1021, 'kills': 1, 'deaths': 1, 'as...
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
#
#                                                     3
# 0                                                None
# 1   {'hero_id': 1023, 'kills': 0, 'deaths': 3, 'as...
# 2   {'hero_id': 1041, 'kills': 1, 'deaths': 2, 'as...
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None

# %% [markdown]
# It would seem this generates an unknown number of columns based on the number of swaps a player makes per match. While this information is necessary fo accurracy (`hit_rate`), I think the length of the matrix could potentially be a better variable itself. (e.g. the more swaps you make, the *less likely* your team is to win)
#
# The number of rows align with the number of players, so per match this could be added back  on the the match_df. Consider:
# - Creating a column containing a string or array of all heroes played per match
# - Creating a column containing the avg accuracy (hit_rate) of heros played per match for each individual entry

# %%
display(hero_df[0][0])
# Out:
# {'hero_id': 1050,
#  'kills': 2,
#  'deaths': 4,
#  'assists': 3,
#  'hit_rate': 0.5477707006369427,
#  'playtime.minutes': 7,
#  'playtime.seconds': 39,
#  'playtime.raw': 459}

# %% [markdown]
# ***
# So we have to go to this low of level to get accuracy from the match data, but to get a list of heros we would also need to reassign the values as well before working with the data.
#
# We likely also want to pull player profile data to check rank and most potentially most played heros. Here's a list of items that might be necessary for analysis:
# - player rank
# - heroes id:name -> we want to grab a list of hero id's and their actual name in game
# - hero role
#
# ***
# ## What are we investigating?
#
# This is the real question. Long since the original hero-shooter (Overwatch) there's been a general consensus of the community at high ranks that "**stats don't matter**". Since Overwatch doesn't have a public API where you amass any of this data, people have just accepted this as *fact*. The idea of this investigation is prove and/or challenge it through a series of questions. Some of the proposed questions are:
#
# - Kills/Deaths/Assists
#     - do these values impact win likelihood?
#     - which one has the strongest correlation with win % ?
#     - does last_hit spread win games or solo carry more impactful?
# - Dmg/Mit/Heal
#     - does healing win games or is it damage?
#     - how much does blocking damage impact the outcome of a game?
# - META
#     - do meta characters have high winrates in general or is it comp dependent?
#     - is tripple support really that strong?
# ***
# # How much data do we need?
#
# ### Estimating the Required Data Size
# A common rule of thumb for machine learning is to have at least 10 times as many samples as features for simple models like logistic regression. For more complex models (e.g., random forests, neural networks), this can be 50–100x or more.
#
# #### **Step 1: Estimate Data Points per Match**
# Since each match involves 12 players, you need to decide if you:
#
# - Treat each player individually → 12 data points per match
# - Aggregate team stats → 2 data points per match
# - Keep match-level stats → 1 data point per match
#
# #### **Step 2: Estimate Required Matches**
# For a simple logistic regression, let’s assume you have 20 features (e.g., damage, KDA, hero, healing, etc.):
#
# - **Logistic Regression** → Needs 200–500 matches (4,000–12,000 player data points)
# - **Random Forest/XGBoost** → Needs 1,000–5,000 matches (20,000–60,000 player data points)
# - **Neural Network** → Needs 5,000+ matches (100,000+ player data points)
#
# Ideally, I want ~5000+ matches as a neural network is most likely to give the best answer to this multifacted problem, however for the nature of this project and time commitment, we'll settle for 1000 matches for the time being.

# %% [markdown]
# ***
# ## Assumptions
#
# It is impossible to account for general player variance (e.g. poor performance due to life events) so we have to consider some factors outside of our control. Here are some reasonable assumptions to be made regarding the game.
#
# ### **1. Players in the top 5%-10% understand the game (*but can't always impact it*)**
#
# The idea here is that you're good enough to be in the top of the upper quartile of the entire playerbase, but you aren't the top 1% who can solo-carry or meaningfully change the game with your presence alone. At this range it's expected:
# - All players generally know what all characters do (abilities/cooldowns/comp-types/etc.)
# - All players are able to somewhat effectively coordinate with a team (regardless of verbal communication)
# - Most players can land skill-shots (i.e. non-targeted abilities) and have a semi-consistent accuracy (for non-melee characters)
# - All players know what the job of their role is, as well as what K/D/A & Dmg/Mit/Heal are
#
# This range mostly consists of Diamond → Grand Master players, but excludes the Celestial rank which is made up of the top 'Carry' players whose presence drastically changes the outcome of the match.
#
# So for this exercise, most match samples will be take from **Diamond** to **Grand Master**, with the exception of a smaller sample pool of lower ranked and/or quickplay games to test against a null group.
#
# **Benefits of Filtering to Upper Ranks**
# - ✅ More Consistent Gameplay → Reduces randomness from players who don’t fully grasp the game.
# - ✅ Better Hero Understanding → Ensures win rates reflect actual hero strengths rather than misplays.
# - ✅ More Useful Insights → The model will be more applicable to serious players looking to improve.
#
# **Potential Downsides**
# - ❌ Less Data Overall → You may need more matches to reach the same level of statistical confidence.
# - ❌ Not Representative of All Players → If you ever want to predict win likelihood for lower-ranked players, the model might not generalize well.
#
# ### **2. Team Coordination vs. Solo-play**
#
# There isn't a great way to check for this other than individually tagging each player in a match and counting how often they appear relative to other players. While possible, it can severly limit the amount of data I can collect since the likelyhood of *N-stack vs N-stack* is high.
#
# **I'll be assuming that if there is a team with N-stack, the enemy team also has a N-stack of equal players.**
#
# ### **3. Match Duration & Early FFs**
#
# Any matches that resulted in a surrender will be removed from the sampling pool. There are unlikely to give data either way that is important. This also includes matches that had leavers.
#
# ### **4. Hero Representation & Meta Considerations**
#
# Some heroes are played far more often than others, which can bias the model.
# - Should you exclude heroes with too little data to avoid inaccurate win rates?
# - Should the model account for patch updates that change hero balance?
#
# To avoid this, a minimum match count per hero will be required before including it in the dataset. If the number of matches the hero appears in strays too far from the mean, then I'll look at the data further to see if they need to be excluded from this analysis or if more matches need to be added.
#
# ***
